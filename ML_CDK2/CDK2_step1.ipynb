# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.9 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.4 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.8 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('CDK2')
targets = pd.DataFrame.from_dict(target_query)
targets.head(2)
# Out:
#   cross_references      organism  pref_name  score  species_group_flag  \
# 0               []  Homo sapiens  CDK2/CDK4   14.0               False
# 1               []  Mus musculus  CDK2/CDK4   14.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL3038517  [{'accession': 'P11802', 'component_descriptio...
# 1    CHEMBL4106185  [{'accession': 'P30285', 'component_descriptio...
#
#       target_type  tax_id
# 0  PROTEIN FAMILY    9606
# 1  PROTEIN FAMILY   10090

# %%
#CHEMBL301

# %%
selected_target = targets.target_chembl_id[9]
selected_target
# Out:
# 'CHEMBL301'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       105376                  []
# 1        None             None       106512                  []
# 2        None             None       107704                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL660784  Inhibitory concentration against cyclin-depend...
# 1    CHEMBL661128  Inhibitory concentration against cyclin-depend...
# 2    CHEMBL661128  Inhibitory concentration against cyclin-depend...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism           target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
# 1    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
# 2    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
#
#    type units    uo_units upper_value   value
# 0  IC50    uM  UO_0000065        None    36.0
# 1  IC50    nM  UO_0000065        None     2.0
# 2  IC50    nM  UO_0000065        None  1000.0
#
# [3 rows x 46 columns]

# %%
len(df)
# Out:
# 2952

# %%
df.target_pref_name.unique()
# Out:
# array(['Cyclin-dependent kinase 2'], dtype=object)

# %%
df.units.unique()
# Out:
# array(['uM', 'nM', None, "10'-6g/ml", "10'-7g/ml", "10'-5g/ml", 'ug ml-1',
#        'microM', 'nmol/L'], dtype=object)

# %%
df.units.value_counts()
# Out:
# units
# uM           1442
# nM           1308
# ug ml-1        42
# 10'-5g/ml       6
# 10'-6g/ml       3
# microM          2
# nmol/L          2
# 10'-7g/ml       1
# Name: count, dtype: int64

# %%
df_sel=df.loc[df['units']=='uM']

# %%
df_sel.units.value_counts()
# Out:
# units
# uM    1442
# Name: count, dtype: int64

# %%
len(df_sel)
# Out:
# 1442

# %%
df_sel.head(2)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       105376                  []
# 4        None             None       108039                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL660784  Inhibitory concentration against cyclin-depend...
# 4    CHEMBL661130            Inhibition of Cyclin-dependent kinase 2
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism           target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
# 4    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
#
#    type units    uo_units upper_value value
# 0  IC50    uM  UO_0000065        None  36.0
# 4  IC50    uM  UO_0000065        None  0.03
#
# [2 rows x 46 columns]

# %%
df2 = df_sel[df_sel.standard_value.notna()]
df2 = df2[df_sel.canonical_smiles.notna()]
# Out:
# <ipython-input-18-4cd1e99d5d9d>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df_sel.canonical_smiles.notna()]

# %%
df2.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       105376                  []
# 4        None             None       108039                  []
# 5        None             None       108796                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL660784  Inhibitory concentration against cyclin-depend...
# 4    CHEMBL661130            Inhibition of Cyclin-dependent kinase 2
# 5    CHEMBL660784  Inhibitory concentration against cyclin-depend...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
# 5          B                    None                   None  BAO_0000190  ...
#
#   target_organism           target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
# 4    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
# 5    Homo sapiens  Cyclin-dependent kinase 2          9606       None  None
#
#    type units    uo_units upper_value value
# 0  IC50    uM  UO_0000065        None  36.0
# 4  IC50    uM  UO_0000065        None  0.03
# 5  IC50    uM  UO_0000065        None   0.2
#
# [3 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1357

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])

# %%
len(df2_nr)
# Out:
# 1357

# %%
df2_nr.units.value_counts()
# Out:
# units
# uM    1357
# Name: count, dtype: int64

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value','units']

# %%
df3 = df2_nr[selection]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL101052     COc1ccc(Nc2ccnc(Nc3ccc(OCC(O)CN(C)C)cc3)n2)cc1
# 4           CHEMBL84944     CC(C)C(CO)Nc1nc(NCc2cccc(O)c2)c2ncn(C(C)C)c2n1
# 5          CHEMBL419720  CN(C)CC(O)COc1ccc(Nc2ncc(Br)c(N(CCCC(F)(F)F)c3...
# 8           CHEMBL86066               CC(C)n1cnc2c(NCc3ccccc3)nc(NCCO)nc21
# 9          CHEMBL101311   CN(C)CC(O)COc1ccc(Nc2nccc(Nc3cc(Cl)ccc3Cl)n2)cc1
# ...                 ...                                                ...
# 2933      CHEMBL4213175              COc1ccncc1NC(=O)c1ccnc(NC(=O)C2CC2)c1
# 2934      CHEMBL5270581       O=C(Nc1cnccc1-c1ccccc1)c1ccnc(NC(=O)C2CC2)c1
# 2935      CHEMBL5288565    O=C(Nc1cnccc1-c1ccc(F)cc1)c1ccnc(NC(=O)C2CC2)c1
# 2936      CHEMBL5278465   O=C(Nc1cnccc1-c1ccc(Cl)cc1)c1ccnc(NC(=O)C2CC2)c1
# 2939      CHEMBL1952030    COc1cc[nH]c1/C=C1\C(=O)Nc2ccc([N+](=O)[O-])cc21
#
#      standard_value units
# 0           36000.0    uM
# 4              30.0    uM
# 5             200.0    uM
# 8            8000.0    uM
# 9            1000.0    uM
# ...             ...   ...
# 2933         2000.0    uM
# 2934         2000.0    uM
# 2935         2000.0    uM
# 2936         2000.0    uM
# 2939        39000.0    uM
#
# [1357 rows x 4 columns]

# %%
df3.to_csv('cdk2.csv', index=False)

# %%
df3.isnull().sum()
# Out:
# molecule_chembl_id    0
# canonical_smiles      0
# standard_value        0
# units                 0
# dtype: int64

# %%
df4 = pd.read_csv('cdk2.csv')

# %% [markdown]
# Divide the data to active and inactive

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) <= 1000:
    bioactivity_threshold.append("active")
  #elif float(i) >= 10000:
      #bioactivity_threshold.append("inactive")
  else:
    bioactivity_threshold.append("inactive")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='activity')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL101052     COc1ccc(Nc2ccnc(Nc3ccc(OCC(O)CN(C)C)cc3)n2)cc1
# 1           CHEMBL84944     CC(C)C(CO)Nc1nc(NCc2cccc(O)c2)c2ncn(C(C)C)c2n1
# 2          CHEMBL419720  CN(C)CC(O)COc1ccc(Nc2ncc(Br)c(N(CCCC(F)(F)F)c3...
# 3           CHEMBL86066               CC(C)n1cnc2c(NCc3ccccc3)nc(NCCO)nc21
# 4          CHEMBL101311   CN(C)CC(O)COc1ccc(Nc2nccc(Nc3cc(Cl)ccc3Cl)n2)cc1
# ...                 ...                                                ...
# 1352      CHEMBL4213175              COc1ccncc1NC(=O)c1ccnc(NC(=O)C2CC2)c1
# 1353      CHEMBL5270581       O=C(Nc1cnccc1-c1ccccc1)c1ccnc(NC(=O)C2CC2)c1
# 1354      CHEMBL5288565    O=C(Nc1cnccc1-c1ccc(F)cc1)c1ccnc(NC(=O)C2CC2)c1
# 1355      CHEMBL5278465   O=C(Nc1cnccc1-c1ccc(Cl)cc1)c1ccnc(NC(=O)C2CC2)c1
# 1356      CHEMBL1952030    COc1cc[nH]c1/C=C1\C(=O)Nc2ccc([N+](=O)[O-])cc21
#
#       standard_value units  activity
# 0            36000.0    uM  inactive
# 1               30.0    uM    active
# 2              200.0    uM    active
# 3             8000.0    uM  inactive
# 4             1000.0    uM    active
# ...              ...   ...       ...
# 1352          2000.0    uM  inactive
# 1353          2000.0    uM  inactive
# 1354          2000.0    uM  inactive
# 1355          2000.0    uM  inactive
# 1356         39000.0    uM  inactive
#
# [1357 rows x 5 columns]

# %%
df5.to_csv('cdk2curated.csv', index=False)

# %%
df5.isnull().sum()
# Out:
# molecule_chembl_id    0
# canonical_smiles      0
# standard_value        0
# units                 0
# activity              0
# dtype: int64

# %%
df5['activity'].value_counts()
# Out:
# activity
# inactive    839
# active      518
# Name: count, dtype: int64

# %% [markdown]
# Labelling the DATA Active=0, inactive =1

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
label_encoder = preprocessing.LabelEncoder()

# %%
df5['activity']= label_encoder.fit_transform(df5['activity'])

# %%
df5['activity'].value_counts()
# Out:
# activity
# 1    839
# 0    518
# Name: count, dtype: int64

# %%
df6 =  df5['canonical_smiles']
df6.to_csv('molecule.smi', sep='\t', index=False, header=False)
df6
# Out:
# 0          COc1ccc(Nc2ccnc(Nc3ccc(OCC(O)CN(C)C)cc3)n2)cc1
# 1          CC(C)C(CO)Nc1nc(NCc2cccc(O)c2)c2ncn(C(C)C)c2n1
# 2       CN(C)CC(O)COc1ccc(Nc2ncc(Br)c(N(CCCC(F)(F)F)c3...
# 3                    CC(C)n1cnc2c(NCc3ccccc3)nc(NCCO)nc21
# 4        CN(C)CC(O)COc1ccc(Nc2nccc(Nc3cc(Cl)ccc3Cl)n2)cc1
#                               ...
# 1352                COc1ccncc1NC(=O)c1ccnc(NC(=O)C2CC2)c1
# 1353         O=C(Nc1cnccc1-c1ccccc1)c1ccnc(NC(=O)C2CC2)c1
# 1354      O=C(Nc1cnccc1-c1ccc(F)cc1)c1ccnc(NC(=O)C2CC2)c1
# 1355     O=C(Nc1cnccc1-c1ccc(Cl)cc1)c1ccnc(NC(=O)C2CC2)c1
# 1356      COc1cc[nH]c1/C=C1\C(=O)Nc2ccc([N+](=O)[O-])cc21
# Name: canonical_smiles, Length: 1357, dtype: object
